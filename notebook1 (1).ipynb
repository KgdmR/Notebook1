# %%
# %%HTML
# <h1>Bonjour les 2nd C</h1>
# Out:
# <h1>Bonjour les 2nd C</h1>

# %%
import ipywidgets as widgets

# %%
file = open("capture d'écran (14).png", "rb")
image = file.read()
widgets.Image(
    value=image,
    format='png',
    width=300,
    height=400,
)

# %%
widgets.IntSlider(
    value=0,
    min=0,
    max=1,
    step=1,
    description='Test:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='d'
)
# Out:
# IntSlider(value=0, continuous_update=False, description='Test:', max=1)
